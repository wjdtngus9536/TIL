# %% [markdown]
# # 1. Introduction
# ---
#
# ### Topic covered
# 1. Professional software development
#     - What is meant by software engineering.
#
#
# 2. Software engineering ethics
#     - A brief introduction to ethical issues that affect software engineering.
#
#
# 3. Case studies
#     - An introduction to three examples that are used in later chapters in the book.
#
# ### 1.0.1 Software engineering
#
#
# ### 1.0.2 Software costs
#
#
# ### 1.0.3 Software project failure

# %% [markdown]
# ## 1.1. Professional software development
# ---
# ### 1.1.1. Frequently asked questions about software engineering
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
#
# ### 1.1.2. Software products
# - Generic products
# - Customized products
#
#
# ### 1.1.3. Product specification
# - Generic products
# - Customized products
#
# ### 1.1.4 Essential attributes of good software
# ![image-3.png](attachment:image-3.png)
#
# |Product characteristic|Description|
# |:-:|:-:|
# |Maintainability|Software should be written in such a way so that it can evolve to meet the changing needs of customers. This is a critical attribute because software change is an inevitable requirement of a changing business environment.
# |Dependability and security||
# |Efficiency||
# |Acceptability||
#
#
# ### 1.1.5. Software engineering
#
# - Software engineering is an engineering discipline that is concerned with all aspects of software production from the early stages of system specification through to maintaining the system after it has gone into use.
# - Engineering discipline
#      - Using appropriate theories and methods to solve problems bearing in mind organizational and financial constraints.
# - All aspects of software production
#      - Not just technical process of development. Also project management and the development of tools, methods etc. to support software production.
#
# ###  1.1.6. General issues that affect software
# 1. Heterogeneity
# 2. Business and social change
# 3. Security and trust
#     - 신뢰성이 무너지면 다시 해야하고
# 4. Scale
#     - 100명 쓰도록 제작된 앱과 10,000명이 다른데, 그 때 마다 서버사이드에서 수정이 필요하다.
#
#
# ### 1.1.7. Application types
# 1. Stand-alone applications
#     - 로컬 컴퓨터에서 돌아가는 시스템들
# 2. Interactive transaction-based applications
#     - Applications that execute on a remote computer and are accessed by users from their own PCs or terminals. These include web applications such as e-commerce applications.
#     - 웹 서비스, 클라우드 서비스, API써서 하는 것들
# 3. Embedded control systems
#     - IOT가 되야 하므로 Interative로 가고 있음
#     - These are software control systems that control and manage hardware devices.
# 4. Batch processing systems
#     - 처리 방식이 They process large numbers of individual inputs to create corresponding outputs.
# 5. Entertainment systems
# 6. Systems for modeling and simulation
# 7. Data collection systems
# 8. Systems of systems
#     - 앞의 것들을 묶어서 통합 시스템을 만들 때
#     - low level이 아님
#
# ### 1.1.8. Software engineering fundamentals
#
# > 스펙이 얼마나 중요한건지 보여주는 동영상? 3.8 인터넷이 안돼 넘어감
# - Some fundamental principles apply to all types of software system, irrespective of the development techniques used:
#     - 소프트웨어 타입의 차이에 따라 다른 개발 과정으로 개발되어야 한다.
#     - Dependability and performance are important for all types of system.
#     - Understanding and managing the software specification and requirements (what the software should do) are important.
#     - Where appropriate, you should reuse software that has already been developed rather than write new software.
#
# 과제를 하더라도 basic 코드들은 class화 할 수 있게 짜서 다음에도 사용할 수 있도록 준비해라. socket programming, protocol..
#
# ### 1.1.9. Internet software engineering
# - 웹 베이스의 시스템을 만든다는 것 자체가 거기서 쓰는 프로토콜 밖에 쓸 수가 없게된다. 다른 것을 할 수 없게 됨. 하지만 보통 브라우저 범위를 벗어나는 개발을 할 일은 없다.
# -
#
#
# ### 1.1.10 Web-based software engineering
# Web-based systems are complex distributed systems
# but the fundamental principles of software engineering
# discussed previously are as applicable to them as they
# are to any other types of system.
#
#
# ### 1.1.11 Web software engineering
# - Software reuse
#     - Software reuse is the dominant approach for constructing webbased systems. When building these systems, you think about how you can assemble them from pre-existing software components and systems.
#     - reuse 잘하는 사람이 되어라. 과제도 open source 써도 상관 없다.
# - Incremental and agile development
#     - It is now generally recognized that it is impractical to specify all the requirements for such systems in advance.
# - Service-oriented systems
#
# - Rich interfaces

# %% [markdown]
# ## 1.2. Software engineering ethics
# ---
#
# 1. Confidentiality You should normally respect the confidentiality of your employers or clients regardless of whether or not a formal confidentiality agreement has been signed.
#
#
# 2. Competence You should not misrepresent your level of competence. You should not knowingly accept work that is outside your competence.
#
#
# 3. Intellectual property rights You should be aware of local laws governing the use of intellectual property such as patents and copyright. You should be careful to ensure that the intellectual property of employers and clients is protected.
#
#
# 4. Computer misuse You should not use your technical skills to misuse other people’s computers. Computer misuse ranges from relatively trivial (game playing on an employer’s machine) to extremely serious (dissemination of viruses or other malware).
#
# 이 이후 윤리 부분 그냥 넘어감

# %% [markdown]
# ## 1.3. Case studies
# ---
#
# 빨리 읽고 넘어가심
