# %% [markdown]
# # Java Script
# ---
#
# ## 1. Introduction
# ---
#
# ### 1.1 Why JS
# 프론트엔드로 쓸 수 있는 유일한 언어, 웹을 지배하는 언어
# 자바 스크립트는 파이썬처럼 설치할 필요가 없다.
# 왜냐하면 자 바스크립트는 모든 브라우저에 내장되어 있다. html, css, javascript
# 대체불가 => 자바 스크립트만 배우면 된다
#
# - 자바스크립트로 할 수 있는 것
#     - Electron을 사용하면 html, css, js만으로 pc 프로그램을 만들 수 있음
#     - 각종 3D 웹사이트 제작
#
# ### 2.2 Online IDE
# 여기서 컨테이너 만들어서 웹으로 코딩 할 수 있음 [replit](https://replit.com/)

# %% [markdown]
# ## 2. First JS Project
# - 어떻게 html과 JS를 연결시킬 수 있는지 이해하게 될 것
#
# ```javascript
# alert("Hi")
# ```
#
# ![image.png](attachment:image.png)
