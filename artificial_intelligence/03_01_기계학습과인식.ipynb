# %% [markdown]
# # 기계 학습과 인식

# %% [markdown]
# ## 기계학습 기초
#
# 기계학습에서 데이터의 중요성
#
# 가장 단순한 iris 데이터로 시작

# %% [markdown]
# ## 인공지능 제품의 설계와 구현
#
# 규칙기반 vs 고전적 기계 학습 vs 딥러닝
# - 규칙 기반 방법 :
# - 기계 학습 방법 :
# - 딥러닝 방법
#
#
# Extra. Supervised Learning vs Few-Shot Learning

# %% [markdown]
# ## 데이터에 대한 이해

# %% [markdown]
# ##  특징 추출과 표현

# %% [markdown]
# ## 필기 숫자 인식

# %% [markdown]
# ## 성능 측정
# 객관적인 성능 측정의 중요성
# - 모델 선택할 때 중요
# - 현장 설치 여부 결정할 때 중요
#
# 일반화 능력
# - 학습에 사용하지 않았던 새로운 데이터에 대한 성능
# - 가장 확실한 방법은 실제 현장에 설치하고 성능 측정 >> 비용 때문에 실제 적용 어려움
# - 주어진 데이터를 분할하여 사용하는 지혜 필요
#
# confusion matrix(혼동 행렬)
# - 분류 별로 옳은 분류와 틀린 분류의 개수를 기록한 행렬
#     - nji는 모델이 i라고 예측했는데 실제 부류는 j인 샘플의 개수
#     ![image.png](attachment:image.png)
#
# 널리 쓰이는 성능 측정 기준
# - 정확률(accuracy)
#
# - 정밀도(precision)
# 위도
# - 재현율(recall)
# 바스
#
#
# T(맞췄다) P(맞다고 판단했다)
# FP : 과검출(오버해서 찾았다.)
# FN : 미검출
#
# ### 훈련 / 검증 / 테스트 집합으로 쪼개기
#
# ### 교차 검증
#
# 데이터셋이 작을 때?

# %% [markdown]
# ## 특징 공간을 분할하는 결정 경계
#
# 비선형 분류, 까다로운 이유 : 과잉 적합 회피
#
#
# Extra. Bias and Variance
# - var: 어떤 샘플이 올지 모르니까 커진다.
# - bias :
#     - overfitting :
#     - underfitting :
