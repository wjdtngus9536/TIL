# %% [markdown]
# 용어 설명 추가
#
#
# 노코드 플랫폼
# 학습 데이터
#
#
# AWS :
# 가상 머신의 최소 스펙
# gpu는 종량제라 쓰는 만큼 비용이 들어감
# 모델이 돌아가는 환경은 cpu에서 돌아가야 한다.
# 메모리는 많이 필요 없을 것 같다. 8~16GB
# 4코어
# HDD는 기본 제공 용량 사용하면 될 듯 하다.
#
# 외부에서 접근이 가능한 공인 IP비용도 산정해야 한다.
# 고정적으로 접근하려면 비용..
#
# 벤치마킹할 때 두 명이 참여할 지 네 명이 참여할 지
# 모델 이해
#
# 간트차트 개개인에 대한 항목들이 나왔으면 좋겠다.
#
# 기대 효과 및 활용 방안 - 논문 쓸 때도 넣어야 하니까 추가적으로 내용 채워 넣었으면 좋겠다.
#
# 시스템 아키텍쳐 - 블록 다이어 그램 같은거 그려 넣었으면 좋겠음
#
#
# 프로세스?..
# 과제 수행할 때 어떤 절차에 맞춰서 진행하게 될 지
# 대략적으로 말씀드린다.
#
# 이걸 토대로 해서 어떤 것들을 해야하는 건지
#
# - 관련 기술, 자료 조사(논문이면 좋다), 연구 배경 쓸 때 논문 내용을 첨언하니 논문 위주의 자료 조사를 할 것이라고 쓰면 좋다
#     - 모델 쪽에는 많은 조언이 있지만 웹 적으로는 보고서 잘못 된 것, DB 부족한 것들 or 부족한 UI요소 조언
#     - 공식 홈페이지 : pytorch.org
#     - 분류기(Classifier) 학습하기
#     - 현황 조사, 유명한 모델을 만들어서 제공하고 있음(다양함)
#     - TorchVision..
#     - 한 사람당 모델 2개 8개 모델 돌려보고서 벤치마킹
# - 모델 설계, 시스템 설계, DB 설계, UI 설계
# - 구현
# - 테스트(단위 테스트, 연동(통합) 테스트)
# - 배포(클라우드)
#
#
# >> 어떤 것들을 기반으로 해서 자료 조사를 할 겁니다.
#
# >> 기능 명세를 명확하게 작성해야 한다.
# >> 기능 명세가 있어야 명확한 조언이 가능하다.
#
# >> 시스템 아키텍처 그릴 때 어떻게 구성이 나오는지 나오려면 RestAPI인지 장고에 태워서 쓰는건지 명확해야 함.
#
#
# # 기능
# - 모델 학습
# - 모델 예측
# - 모델 <-> 웹서버 인터페이스
#     - 이게 가장 우선 되어야 한다.
#     - 인터페이싱을 통해서 어찌돼었든
#
#
#
# 웹개발
# - 회원 관리
#     - 각자 학습 모델 만들고 할텐데 다중 작업이 일어났을 때 데이터를 어떻게 관리할 것인가에 대해 고민을 많이 해봐야 할 것
#     - DB설계 잘 되어야 한다.
# - 학습데이터 수집 -> 캠, 파일 업로드
# - 학습데이터 구축 -> 클래스 부여
# - 모델 학습 -> 데이터셋 선택, 학습 시작
# - 모델 모니터링(시간, 정확도, 반복 학습 횟수) - 1hr쯤
# - 모델 예측 -> 결과(이미지 한 장 씩?, 웹 실시간 높은 프레임)
#
#
# - 모델 서비스, 추출 (코드 생성 기능도 있어야 하지 않을까?.. 다른 서비스와 연동하기 위해)
#     - RESTFUL로 모델을 실행하고 결과를 가져오게 하고?
#     - 모델 코드 생성 + 저장을 하면.. pytorch에서 활용 가능한 binary 파일이 만들어진다. save load 하듯이 활용하게 될 것 *.pt
#     - 향후 연구 방향
#
#
#
#
# DB 데이터 관리
# - 회원 관리
# - 학습데이터 관리, 테이블도 여러개로 분해될 것 여러가지 index 테이블도 써야하고..
# - 모델 관리
#
#
#
# 한 과장님과 미팅 할 때, 문서기반으로 얘기해야 함.
#     - 모델 벤치마킹 보고서 -> 모델 종류, 성능 결과, 선정 이유가 논리적으로 맞아야 한다.
#     - 모델, 웹 백엔드-프론트엔드 -> 인터페이스 정의서 무조건 나와야 함.
#     - 화면 설계서
#     - DB 테이블 정의서
#     - 기능 정의서 -> 간트 차트(일정)
#
#
# 기존에 하고 있던 것과 차이점이 뭔지 고민해 봐야 한다.
#     - 어느 게 부족해서 이런 차별점이 있기 때문에 만든다가 있어야 한다 -> 어떤 아이디어를 내야 할 지
#
#
# 거창한 문서가 아니라 미리미리 만들어 놔야 한다.
