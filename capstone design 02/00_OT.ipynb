# %% [markdown]
# # OT
# ---
#
# ## 1. 팀 구성 및 회의
#
# - 멘토와 매주 1회 이상 회의(온라인 or 오프라인)
# - 학기 중 1~2회 대면 (오프라인)회의 : 인증사진 필수!
#
# - 학생팀별 회의 : 매주 1 ~ 2회 (멘토 회의 포함)
# - 발표는 팀원이 번갈아 가면서 발표(반드시 1번 이상 발표할 것) : 총 5회(중간, 최종 포함)
#
# - **멘토님과 언제 어떤 방식으로 미팅을 할 것인지 계획이 세워져 있어야 한다.**
#
# ## 2. 프로젝트 수행
#
# - Github 기반 협업
# - 팀장 계정으로 project repository 생성
# - 팀원계정 collaborators 등록
#     - Private Repo로 개설하는 경우 튜터 계정 등록 필요 (향후 공지)
#
# ###  Github 관련 문의
# - TA: 최지오(snowgeo@gmail.com), github 계정 : GeoChoi
#
#
# ### 팀당 수행실적 필수 요건 (1개 이상)
# - 국내학회논문발표 / 특허출원 / SW저작권 / 앱등록 / 기술백서(기업)
#     - 논문, 특허, SW저작권 팀원 이름이 게재되어야 함
#     - 앱등록 별도 양식 제공 예정(개인 이름 아니어도 ok)
#
#
# ## 3. 수업 일정
#
# `간트차트 꼭 포함하여 작성할 것` -> exel?
#
# 1. ~ 03/07 : 5지망까지 제출
# 2. ~ 03/20 : 수행계획발표(한 주씩 미룸)
# 3. ~ 03/27 : 수행계획서 제출(ASAP)3
#
# - 중간 발표, 총 3회
#     - 1차 4/3, 2차 5/1, 3차 5/29
#
# - 최종결과발표 : 6/19(월)
# - 결과보고서 제출 ~6/25(일)
# - 평가지 제출 ~6/27(화)
#
# 24분대 최종발표 설명:
# - 최종 발표 내용은 Logical하게 간다. 소프트웨어 공학적인 내용은 보고서에만 넣고
# - 발표는 요약적으로
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. 재료비 - 설명회 때 설명 예정
#
# - 클라우드비용의 경우, 멘토(기업)를 통해서 지원가능 (멘토 - 담당교수 논의)
#
# - 논문 등록 및 여비
#     - 학회논문 등록비 지원 (발표자 1명)
#     - 논문발표를 위한 여비 지원 (발표 당일)
#     - 개인 카드 사용하면 안됨, 학교카드로 결제해야 함.

# %% [markdown]
# ## 5. 프로젝트 수행 실적
#
# - 논문 (국내 학술대회 발표)
#     - 교신저자 영문이름/이메일 : Seoul-Yeong Jeong / snowflower@knu.ac.kr
# - `실적 제출에 대해 기업 멘토와 반드시 논의 후 작성할 것` - 이번 주 멘토님과 상의
# - 논문 제출 전 정설영 교수님 확인 받고 피드백대로 수정(최소 일주일 전 제출할 것)

# %% [markdown]
# ## 6. 산학협력프로젝트 리스트
#
# - 녹음 40분대
# -
